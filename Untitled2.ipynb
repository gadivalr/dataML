# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d= {'a':10,'b':20,'c':30}
plt.bar(x=d.keys(),height=d.values())
plt.title('Bar plot')
plt.show()

# %%
plt.pie(x=d.values(),labels=d.keys())
plt.title('Pie Chart')
plt.show()
