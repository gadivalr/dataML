# %% [markdown]
# Problem Statement
# Consider a random experiment of tossing a biased coin 6 times where the probability of getting a head is 0.6. If getting head is considered as 'success', then the binomal distribution table will contain the probability of r successes for each possible value of r.

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt

# %%
n=6
p=0.6

# %%
r_values = list(range(n+1))

# %%
mean, var =binom.stats(n,p)

# %%
dist = [binom.pmf(r,n,p) for r in r_values]

# %%
print("r\tp(r)")
for i in range(n+1):
    print(str(r_values[i]) + "\t" + str(dist[i]))
# Out:
# r	p(r)
# 0	0.0040960000000000015
# 1	0.03686400000000002
# 2	0.1382400000000001
# 3	0.2764800000000001
# 4	0.3110400000000001
# 5	0.1866240000000001
# 6	0.04665599999999999

# %%
plt.bar(r_values,dist)
plt.show()
